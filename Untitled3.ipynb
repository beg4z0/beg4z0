# %%
from collections import Counter
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import ngrams
nltk_resources = ["stopwords", "punkt", "wordnet"]
for resource in nltk_resources:
    nltk.download(resource)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read in data, print column names and dtypes
df = pd.read_csv('/content/drive/My Drive/Reviews.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      568454 non-null  int64
#  1   ProductId               568454 non-null  object
#  2   UserId                  568454 non-null  object
#  3   ProfileName             568438 non-null  object
#  4   HelpfulnessNumerator    568454 non-null  int64
#  5   HelpfulnessDenominator  568454 non-null  int64
#  6   Score                   568454 non-null  int64
#  7   Time                    568454 non-null  int64
#  8   Summary                 568427 non-null  object
#  9   Text                    568454 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 43.4+ MB

# %%
# let joins all the title rows and tokenize them into words
comments = " ".join(df['Summary'].astype(str))
words = word_tokenize(comments)

# %%
#lets creat a small function to clean the words of punctuations, stop words and lemmatize the words
def clean_words(new_tokens):
    new_tokens = [t.lower() for t in new_tokens]
    new_tokens =[t for t in new_tokens if t not in stopwords.words('english')]
    new_tokens = [t for t in new_tokens if t.isalpha()]
    lemmatizer = WordNetLemmatizer()
    new_tokens =[lemmatizer.lemmatize(t) for t in new_tokens]
    return new_tokens

# %%
lowered = clean_words(words)

# %%
bow = Counter(lowered)
bow
# Out:
# Counter({'good': 51789,
#          'quality': 5580,
#          'dog': 21072,
#          'food': 13732,
#          'advertised': 522,
#          'delight': 615,
#          'say': 1444,
#          'cough': 116,
#          'medicine': 155,
#          'great': 72858,
#          'taffy': 144,
#          'nice': 6010,
#          'expensive': 2318,
#          'brand': 1477,
#          'wonderful': 5593,
#          'tasty': 11088,
#          'yay': 149,
#          'barley': 81,
#          'healthy': 6943,
#          'best': 33426,
#          'hot': 4726,
#          'sauce': 2768,
#          'world': 972,
#          'cat': 11116,
#          'love': 35873,
#          'diet': 1471,
#          'better': 7369,
#          'regular': 1010,
#          'fan': 875,
#          'new': 2382,
#          'fresh': 2511,
#          'greasy': 179,
#          'strawberry': 437,
#          'twizzlers': 39,
#          'yummy': 10831,
#          'lot': 1399,
#          'expect': 294,
#          'poor': 1332,
#          'taste': 24018,
#          'sweet': 5566,
#          'candy': 3167,
#          'home': 884,
#          'delivered': 201,
#          'twizlers': 2,
#          'always': 1165,
#          'delicious': 18814,
#          'product': 20622,
#          'please': 891,
#          'sell': 162,
#          'mexico': 56,
#          'nasty': 664,
#          'flavor': 14954,
#          'bargain': 381,
#          'price': 11315,
#          'machine': 447,
#          'instant': 1427,
#          'oatmeal': 1242,
#          'irish': 175,
#          'hurry': 39,
#          'satisfying': 608,
#          'gluten': 2943,
#          'free': 5045,
#          'way': 3380,
#          'start': 377,
#          'day': 1372,
#          'wife': 419,
#          'favorite': 10223,
#          'breakfast': 2072,
#          'would': 1932,
#          'buy': 5005,
#          'mcanns': 2,
#          'lover': 1627,
#          'convenience': 369,
#          'hearty': 197,
#          'mushy': 106,
#          'next': 207,
#          'time': 2379,
#          'wo': 858,
#          'order': 1156,
#          'variety': 1096,
#          'pack': 1775,
#          'stuff': 8304,
#          'like': 14457,
#          'came': 298,
#          'back': 1024,
#          'go': 2671,
#          'nut': 1753,
#          'peanut': 1943,
#          'as': 44,
#          'kickin': 11,
#          'roast': 1464,
#          'smooth': 2042,
#          'brew': 745,
#          'guest': 78,
#          'awesome': 6381,
#          'deal': 2639,
#          'wrong': 1147,
#          'awsome': 203,
#          'kid': 2284,
#          'neighborhood': 14,
#          'loved': 1972,
#          'u': 713,
#          'target': 55,
#          'pretty': 3130,
#          'stale': 1310,
#          'hammer': 26,
#          'nutrition': 555,
#          'fizz': 35,
#          'rock': 863,
#          'source': 432,
#          'electrolyte': 54,
#          'preventing': 4,
#          'cramp': 165,
#          'low': 2360,
#          'carb': 613,
#          'alternative': 2190,
#          'gatorade': 61,
#          'much': 3686,
#          'pay': 334,
#          'bag': 2407,
#          'chocolate': 6601,
#          'pretzel': 1040,
#          'gummi': 253,
#          'bigger': 133,
#          'ever': 9535,
#          'latice': 2,
#          'tart': 428,
#          'warning': 707,
#          'sugar': 3770,
#          'nothing': 1377,
#          'special': 807,
#          'tea': 22573,
#          'cold': 550,
#          'weather': 83,
#          'forget': 127,
#          'molecular': 6,
#          'gastronomy': 4,
#          'rockes': 1,
#          'coffee': 25207,
#          'creamer': 175,
#          'natural': 2391,
#          'balance': 239,
#          'lamb': 179,
#          'rice': 1894,
#          'increased': 37,
#          'itching': 10,
#          'allergy': 744,
#          'stomach': 447,
#          'problem': 871,
#          'life': 1033,
#          'sensitive': 377,
#          'mmmmm': 299,
#          'convenient': 1696,
#          'perfect': 5769,
#          'english': 397,
#          'bulldog': 55,
#          'bad': 5056,
#          'wise': 39,
#          'star': 1768,
#          'item': 1661,
#          'support': 71,
#          'omaha': 61,
#          'apple': 804,
#          'tartlet': 14,
#          'disappointing': 1025,
#          'wasting': 8,
#          'vinegar': 551,
#          'cucumber': 19,
#          'shame': 64,
#          'asparagus': 19,
#          'bliss': 112,
#          'idea': 877,
#          'angel': 64,
#          'puff': 284,
#          'every': 1081,
#          'green': 3528,
#          'freah': 4,
#          'bright': 75,
#          'clean': 606,
#          'review': 2686,
#          'cooky': 3901,
#          'everyday': 320,
#          'cookie': 1705,
#          'far': 1677,
#          'older': 220,
#          'feline': 225,
#          'uti': 36,
#          'palatable': 50,
#          'allergic': 173,
#          'kitty': 1089,
#          'holistic': 119,
#          'select': 84,
#          'spicy': 1511,
#          'ramen': 257,
#          'burn': 118,
#          'amazing': 4264,
#          'last': 980,
#          'bite': 677,
#          'value': 3483,
#          'cheaper': 938,
#          'locally': 133,
#          'look': 919,
#          'beautiful': 549,
#          'happy': 2654,
#          'face': 92,
#          'simply': 1145,
#          'excellent': 13226,
#          'saver': 363,
#          'snack': 8597,
#          'licorice': 886,
#          'sized': 166,
#          'kick': 467,
#          'broken': 596,
#          'bottle': 787,
#          'bottom': 67,
#          'salsa': 281,
#          'ehhh': 33,
#          'cornmeal': 20,
#          'marinade': 211,
#          'rip': 330,
#          'tasting': 4927,
#          'sea': 441,
#          'salt': 2954,
#          'iodine': 6,
#          'simple': 540,
#          'greatest': 479,
#          'right': 1561,
#          'size': 1295,
#          'tasteless': 315,
#          'calorie': 1522,
#          'sooooo': 109,
#          'banana': 405,
#          'runt': 24,
#          'head': 100,
#          'worked': 462,
#          'ricore': 1,
#          'forever': 110,
#          'fluffy': 80,
#          'soft': 805,
#          'sugary': 152,
#          'teen': 26,
#          'lemon': 921,
#          'juice': 991,
#          'handy': 358,
#          'realemon': 5,
#          'amazon': 2762,
#          'relaxing': 159,
#          'almost': 959,
#          'something': 810,
#          'smoke': 102,
#          'never': 1293,
#          'paid': 62,
#          'marley': 170,
#          'mellow': 191,
#          'mood': 29,
#          'lite': 91,
#          'half': 464,
#          'lemonade': 122,
#          'help': 979,
#          'sleep': 245,
#          'chip': 6327,
#          'garbonzo': 2,
#          'bean': 1984,
#          'flour': 710,
#          'yum': 5709,
#          'falafel': 16,
#          'make': 3507,
#          'fruit': 1416,
#          'light': 1625,
#          'miracle': 385,
#          'ok': 3155,
#          'health': 1189,
#          'benefit': 294,
#          'arrived': 579,
#          'lunch': 407,
#          'little': 4392,
#          'mint': 898,
#          'pricey': 1017,
#          'altoids': 121,
#          'mini': 485,
#          'tin': 189,
#          'sugarfree': 55,
#          'small': 1594,
#          'reusable': 16,
#          'container': 311,
#          'huge': 404,
#          'hit': 864,
#          'office': 233,
#          'wintergreen': 29,
#          'breath': 244,
#          'average': 538,
#          'fat': 1106,
#          'senior': 110,
#          'citizen': 9,
#          'nearly': 165,
#          'killed': 35,
#          'changed': 697,
#          'formula': 1253,
#          'sick': 443,
#          'case': 225,
#          'looking': 670,
#          'different': 1172,
#          'correct': 88,
#          'mccormick': 59,
#          'ahmad': 49,
#          'loose': 303,
#          'imperial': 6,
#          'blend': 2112,
#          'fragrant': 209,
#          'real': 2553,
#          'bloody': 71,
#          'mary': 97,
#          'mixer': 71,
#          'mcclures': 1,
#          'mix': 3569,
#          'really': 5661,
#          'give': 999,
#          'watermelon': 80,
#          'citron': 2,
#          'furniture': 17,
#          'polish': 13,
#          'big': 1778,
#          'tub': 51,
#          'neutral': 44,
#          'quantity': 237,
#          'deceitful': 8,
#          'eukanuba': 6,
#          'puppy': 1170,
#          'breed': 118,
#          'high': 2407,
#          'gave': 266,
#          'wicked': 47,
#          'gas': 279,
#          'omg': 517,
#          'jelly': 482,
#          'belly': 300,
#          'anytime': 182,
#          'cup': 4118,
#          'get': 3298,
#          'store': 1361,
#          'disappointed': 2085,
#          'kcups': 176,
#          'keep': 1017,
#          'dentest': 1,
#          'chair': 4,
#          'super': 1946,
#          'superfoods': 7,
#          'easy': 3673,
#          'pok': 5,
#          'chop': 31,
#          'sad': 95,
#          'outcome': 3,
#          'energy': 1696,
#          'shot': 174,
#          'waste': 824,
#          'money': 1775,
#          'ca': 2383,
#          'handle': 63,
#          'caffeine': 439,
#          'yummier': 5,
#          'reek': 4,
#          'chemical': 312,
#          'lifestyle': 37,
#          'raw': 614,
#          'manufacturing': 29,
#          'diminish': 2,
#          'terrible': 1593,
#          'agricultural': 1,
#          'practice': 27,
#          'lie': 87,
#          'use': 2117,
#          'white': 967,
#          'thanks': 376,
#          'scott': 11,
#          'weak': 1459,
#          'packaging': 2065,
#          'priced': 506,
#          'lack': 176,
#          'rotel': 6,
#          'save': 662,
#          'daily': 282,
#          'basis': 12,
#          'fabulous': 1203,
#          'mild': 982,
#          'enough': 1472,
#          'lol': 116,
#          'sure': 869,
#          'organic': 3786,
#          'fantastic': 3269,
#          'guayaki': 8,
#          'provides': 25,
#          'rocket': 23,
#          'work': 4610,
#          'boost': 319,
#          'tasted': 1094,
#          'tested': 75,
#          'trucker': 2,
#          'drink': 3242,
#          'without': 1624,
#          'artificial': 588,
#          'ingredient': 1928,
#          'getting': 311,
#          'awful': 1199,
#          'barely': 133,
#          'describe': 67,
#          'could': 1645,
#          'vanilla': 1946,
#          'tootsie': 65,
#          'roll': 294,
#          'one': 6192,
#          'favoritte': 1,
#          'wow': 2076,
#          'dissapointed': 185,
#          'swiss': 111,
#          'chalet': 1,
#          'oyster': 44,
#          'absolutely': 1582,
#          'gag': 73,
#          'gift': 2041,
#          'fast': 1593,
#          'penguin': 7,
#          'pooper': 4,
#          'hazelnut': 797,
#          'shipped': 246,
#          'art': 35,
#          'yes': 857,
#          'king': 146,
#          'seasoning': 1098,
#          'toasted': 80,
#          'sesame': 213,
#          'oil': 2672,
#          'eating': 741,
#          'whole': 1103,
#          'veggie': 481,
#          'brush': 26,
#          'ice': 591,
#          'teething': 44,
#          'impressed': 542,
#          'feeder': 11,
#          'exactly': 741,
#          'expected': 1857,
#          'line': 226,
#          'swedish': 45,
#          'pearl': 100,
#          'belgian': 87,
#          'wine': 387,
#          'maker': 292,
#          'olive': 899,
#          'weaver': 11,
#          'treat': 10363,
#          'bitter': 1423,
#          'drinking': 327,
#          'latin': 5,
#          'america': 86,
#          'aroma': 629,
#          'bar': 4769,
#          'find': 2175,
#          'anywhere': 268,
#          'else': 513,
#          'granola': 1021,
#          'another': 1018,
#          'husband': 500,
#          'surprise': 456,
#          'highly': 875,
#          'recommended': 977,
#          'saving': 164,
#          'grace': 25,
#          'mountain': 789,
#          'nantucket': 113,
#          'chicken': 1746,
#          'noodle': 1061,
#          'soup': 1904,
#          'since': 238,
#          'slice': 98,
#          'bread': 1666,
#          'deliciously': 179,
#          'scrumptious': 245,
#          'heinz': 66,
#          'porcini': 25,
#          'mushroom': 203,
#          'mostly': 281,
#          'large': 477,
#          'piece': 441,
#          'highest': 106,
#          'valentine': 57,
#          'winner': 491,
#          'near': 82,
#          'wild': 398,
#          'chick': 27,
#          'brown': 639,
#          'ham': 108,
#          'base': 232,
#          'msg': 302,
#          'delisious': 12,
#          'pancake': 594,
#          'around': 884,
#          'arrowhead': 34,
#          'mill': 319,
#          'grain': 723,
#          'buttermilk': 44,
#          'egg': 332,
#          'shipping': 1798,
#          'soothing': 256,
#          'minty': 169,
#          'take': 687,
#          'second': 424,
#          'read': 553,
#          'french': 848,
#          'franch': 1,
#          'double': 320,
#          'pleasure': 228,
#          'single': 320,
#          'guy': 149,
#          'acquired': 165,
#          'elsewhere': 195,
#          'hey': 76,
#          'famous': 51,
#          'reason': 171,
#          'god': 315,
#          'hard': 2100,
#          'kettle': 404,
#          'potato': 1166,
#          'fully': 41,
#          'loaded': 101,
#          'baked': 463,
#          'crunchy': 1473,
#          'glad': 410,
#          'oz': 587,
#          'slight': 127,
#          'jalapeno': 247,
#          'onion': 234,
#          'ridiculously': 106,
#          'pucker': 40,
#          'thick': 254,
#          'quite': 1135,
#          'salty': 1529,
#          'vinegary': 23,
#          'unique': 539,
#          'thai': 331,
#          'honey': 1379,
#          'dijon': 37,
#          'leaf': 900,
#          'aftertaste': 672,
#          'ny': 41,
#          'cheddar': 235,
#          'yowzah': 14,
#          'tangy': 295,
#          'goodness': 914,
#          'heavy': 262,
#          'crisp': 473,
#          'bbq': 527,
#          'cost': 660,
#          'barbeque': 84,
#          'perfection': 250,
#          'supreme': 92,
#          'oooh': 25,
#          'want': 931,
#          'gaain': 14,
#          'twenty': 22,
#          'pound': 282,
#          'control': 368,
#          'whatsoever': 62,
#          'addicitive': 15,
#          'become': 129,
#          'chippoisseur': 56,
#          'finally': 1319,
#          'superbowl': 15,
#          'scooores': 14,
#          'knee': 32,
#          'cheese': 1271,
#          'sour': 659,
#          'cream': 750,
#          'beat': 403,
#          'resist': 67,
#          'spice': 1403,
#          'addictive': 1331,
#          'crunchiness': 20,
#          'moisture': 52,
#          'cooked': 100,
#          'used': 1111,
#          'firm': 73,
#          'creamy': 530,
#          'chivey': 14,
#          'prefer': 369,
#          'habit': 72,
#          'forming': 37,
#          'even': 1668,
#          'already': 120,
#          'oh': 922,
#          'indulgence': 89,
#          'unsalted': 68,
#          'yet': 867,
#          'companion': 47,
#          'wont': 99,
#          'touch': 380,
#          'maybe': 546,
#          'worst': 993,
#          'boulder': 15,
#          'malt': 91,
#          'lightly': 125,
#          'salted': 117,
#          'heavily': 35,
#          'first': 1445,
#          'tang': 65,
#          'crunch': 746,
#          'period': 265,
#          'extra': 766,
#          'snob': 120,
#          'alert': 94,
#          'gourmet': 522,
#          'powerful': 142,
#          'horrible': 1592,
#          'miss': 377,
#          'burnt': 205,
#          'gaaak': 14,
#          'extreme': 87,
#          'absotively': 14,
#          'posilutely': 14,
#          'gone': 450,
#          'hill': 86,
#          'completely': 190,
#          'ripped': 72,
#          'c': 218,
#          'h': 129,
#          'p': 102,
#          'r': 213,
#          'b': 320,
#          'k': 1161,
#          'e': 315,
#          'beware': 1466,
#          'buying': 517,
#          'rancid': 202,
#          'tiniest': 15,
#          'bit': 1693,
#          'disgusting': 647,
#          'strong': 2928,
#          'dripping': 19,
#          'added': 452,
#          'garbage': 178,
#          'madhouse': 24,
#          'munchies': 57,
#          'sold': 181,
#          'damaged': 312,
#          'hole': 51,
#          'stain': 81,
#          'mouse': 38,
#          'orgasmic': 22,
#          'punch': 225,
#          'cant': 140,
#          'believe': 438,
#          'york': 43,
#          'fart': 48,
#          'smell': 2050,
#          'thing': 2035,
#          'addicted': 564,
#          'happened': 211,
#          'recipe': 733,
#          'yoli': 14,
#          'skin': 408,
#          'lip': 63,
#          'sodium': 449,
#          'smile': 81,
#          'service': 1992,
#          'decently': 26,
#          'spiced': 179,
#          'close': 525,
#          'expiration': 461,
#          'date': 909,
#          'eat': 2516,
#          'year': 1037,
#          'defacto': 14,
#          'standard': 277,
#          'caution': 244,
#          'kiss': 65,
#          'tummy': 406,
#          'dont': 322,
#          'know': 856,
#          'expired': 299,
#          'stock': 246,
#          'sometimes': 147,
#          'crispy': 432,
#          'robust': 299,
#          'smaller': 371,
#          'need': 1748,
#          'made': 2614,
#          'mistake': 149,
#          'vickie': 14,
#          'well': 1904,
#          'balanced': 223,
#          'earl': 692,
#          'grey': 707,
#          'success': 100,
#          'shrimp': 96,
#          'stir': 66,
#          'fry': 166,
#          'true': 572,
#          'bavarian': 12,
#          'creme': 221,
#          'oldest': 2,
#          'still': 1414,
#          'michigan': 30,
#          'caramel': 482,
#          'baking': 650,
#          'topping': 104,
#          'tip': 190,
#          'using': 242,
#          'agave': 227,
#          'weigh': 10,
#          'fluid': 15,
#          'ounce': 266,
#          'sweetner': 190,
#          'syrup': 1533,
#          'substitute': 1124,
#          'sweetener': 651,
#          'replacing': 8,
#          'nectar': 158,
#          'found': 1503,
#          'ask': 79,
#          'widely': 28,
#          'available': 740,
#          'plocky': 42,
#          'smokey': 143,
#          'chipotle': 125,
#          'tortill': 8,
#          'faboo': 8,
#          'dangerous': 227,
#          'prone': 28,
#          'binge': 10,
#          'grow': 111,
#          'tortilla': 332,
#          'eaten': 231,
#          'got': 1289,
#          'country': 204,
#          'instead': 337,
#          'chili': 694,
#          'three': 394,
#          'gum': 1365,
#          'stop': 415,
#          'carrying': 35,
#          'om': 41,
#          'nom': 436,
#          'schrumshist': 8,
#          'music': 16,
#          'palate': 65,
#          'kept': 81,
#          'secret': 233,
#          'additive': 132,
#          'fanfreakintastic': 8,
#          'smokin': 37,
#          'red': 1187,
#          'meh': 473,
#          'label': 268,
#          'misleading': 659,
#          'kind': 1170,
#          'bland': 740,
#          'black': 1458,
#          'timely': 63,
#          'delivery': 894,
#          'cute': 369,
#          'surprising': 73,
#          'unparalleled': 7,
#          'side': 323,
#          'perhaps': 106,
#          'batch': 336,
#          'drain': 19,
#          'disappointment': 381,
#          'frosting': 78,
#          'cherrybrook': 5,
#          'kitchen': 348,
#          'dum': 2,
#          'dums': 2,
#          'pop': 960,
#          'fridge': 35,
#          'meat': 611,
#          'smoothie': 105,
#          'perversion': 1,
#          'annie': 107,
#          'homegrown': 16,
#          'wheat': 732,
#          'shell': 148,
#          'macaroni': 56,
#          'cuttiest': 1,
#          'century': 13,
#          'city': 70,
#          'steam': 7,
#          'soy': 638,
#          'mainly': 17,
#          'vote': 35,
#          'though': 555,
#          'kikkoman': 21,
#          'anything': 446,
#          'supermarket': 135,
#          'outstanding': 924,
#          'non': 142,
#          'gmo': 87,
#          'amazingly': 256,
#          'laxative': 55,
#          'joe': 297,
#          'tassimo': 130,
#          'note': 119,
#          'rating': 222,
#          'seller': 457,
#          'kona': 292,
#          'wafer': 258,
#          'tao': 8,
#          'sampler': 266,
#          'milka': 22,
#          'dad': 120,
#          'liked': 743,
#          'family': 906,
#          'kleri': 1,
#          'cranberry': 236,
#          'ferret': 37,
#          'edible': 279,
#          'speedy': 43,
#          'son': 839,
#          'making': 451,
#          'adult': 399,
#          'supervision': 9,
#          'age': 129,
#          'neat': 65,
#          'project': 18,
#          'spongetastic': 2,
#          'twice': 164,
#          'rudolph': 2,
#          'gingerbread': 74,
#          'house': 808,
#          'fun': 1110,
#          'paint': 21,
#          'horrid': 58,
#          'bud': 124,
#          'none': 240,
#          'greater': 15,
#          'heaven': 918,
#          'heavenly': 240,
#          'action': 70,
#          'choclate': 39,
#          'serious': 161,
#          'buck': 182,
#          'overpriced': 1014,
#          'gold': 325,
#          'box': 1466,
#          'seems': 527,
#          'quick': 1529,
#          'arrival': 73,
#          'basket': 256,
#          'adorable': 53,
#          'presentation': 62,
#          'specialty': 36,
#          'party': 321,
#          'liquor': 28,
#          'scottie': 11,
#          'odd': 250,
#          'fake': 254,
#          'sugarless': 38,
#          'stronger': 120,
#          'bubble': 149,
#          'blowing': 8,
#          'imo': 66,
#          'weight': 596,
#          'loss': 142,
#          'royal': 130,
#          'canin': 62,
#          'cocker': 9,
#          'buster': 77,
#          'human': 133,
#          'rave': 64,
#          'rolled': 36,
#          'oat': 440,
#          'uk': 28,
#          'india': 99,
#          'version': 411,
#          'cadbury': 35,
#          'mediocre': 237,
#          'cheap': 689,
#          'consistently': 123,
#          'flavorful': 1173,
#          'purist': 17,
#          'addict': 189,
#          'fine': 1115,
#          'full': 851,
#          'lea': 10,
#          'traditional': 173,
#          'soda': 825,
#          'aluminum': 26,
#          'interesting': 524,
#          'info': 143,
#          'mm': 64,
#          'funny': 188,
#          'pocky': 23,
#          'stick': 764,
#          'melt': 203,
#          'japanese': 127,
#          'dipped': 23,
#          'manga': 1,
#          'local': 314,
#          'wait': 218,
#          'till': 27,
#          'fall': 251,
#          'together': 84,
#          'wanted': 558,
#          'berry': 563,
#          'lowered': 14,
#          'overall': 190,
#          'child': 264,
#          'wary': 30,
#          'recomended': 17,
#          'vile': 61,
#          'strictly': 14,
#          'break': 252,
#          'easily': 180,
#          'twin': 123,
#          'subscription': 152,
#          'fair': 308,
#          'dessert': 405,
#          'nutritional': 260,
#          'repeated': 8,
#          'jar': 427,
#          'runny': 92,
#          'protein': 1674,
#          'vitamin': 300,
#          'baby': 2632,
#          'lilly': 7,
#          'thumb': 213,
#          'earth': 551,
#          'lentil': 113,
#          'dinner': 355,
#          'plastic': 432,
#          'stage': 31,
#          'constipation': 84,
#          'issue': 465,
#          'thin': 375,
#          'place': 185,
#          'picky': 1146,
#          'compared': 160,
#          'others': 379,
#          'shredded': 51,
#          'daughter': 544,
#          'eats': 250,
#          'everything': 512,
#          'dish': 293,
#          'toss': 24,
#          'jarred': 28,
#          'ate': 214,
#          'watery': 264,
#          'eb': 12,
#          'yumminess': 47,
#          'geat': 32,
#          'garbanzo': 29,
#          'mom': 559,
#          'allday': 1,
#          'easrly': 1,
#          'v': 202,
#          'yey': 1,
#          'dark': 1979,
#          'sassafras': 7,
#          'tasten': 1,
#          'lovely': 575,
#          'sas': 1,
#          'paste': 280,
#          'gravy': 248,
#          'yeeeee': 1,
#          'hawww': 1,
#          'pioneer': 7,
#          'eco': 17,
#          'online': 203,
#          'quickly': 268,
#          'delish': 672,
#          'rooibos': 184,
#          'matcha': 339,
#          'moore': 8,
#          'people': 711,
#          'run': 242,
#          'shiznit': 2,
#          'habanero': 60,
#          'babka': 7,
#          'rose': 218,
#          'safety': 49,
#          'freshness': 132,
#          'seal': 122,
#          'truffle': 385,
#          'warm': 197,
#          'ideal': 128,
#          'mueslix': 5,
#          'actual': 101,
#          'muesli': 83,
#          'contains': 613,
#          'trans': 60,
#          'fructose': 139,
#          'corn': 1031,
#          'superior': 265,
#          'cereal': 2758,
#          'bring': 221,
#          'kellogg': 96,
#          'muselix': 1,
#          'grocery': 343,
#          'ur': 3,
#          'ceral': 17,
#          'buyer': 414,
#          'delicate': 155,
#          ...})

# %%
data = pd.DataFrame(bow.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
data =data.head(20)

# %%
sns.barplot(x='frequency',y='word',data=data)
# Out:
# <Axes: xlabel='frequency', ylabel='word'>

# %%
bow2 =Counter(ngrams(lowered,2))
bow2
# Out:
# Counter({('good', 'quality'): 869,
#          ('quality', 'dog'): 200,
#          ('dog', 'food'): 2952,
#          ('food', 'advertised'): 2,
#          ('advertised', 'delight'): 1,
#          ('delight', 'say'): 1,
#          ('say', 'cough'): 1,
#          ('cough', 'medicine'): 14,
#          ('medicine', 'great'): 9,
#          ('great', 'taffy'): 5,
#          ('taffy', 'nice'): 2,
#          ('nice', 'taffy'): 1,
#          ('taffy', 'great'): 9,
#          ('great', 'good'): 587,
#          ('good', 'expensive'): 130,
#          ('expensive', 'brand'): 9,
#          ('brand', 'wonderful'): 5,
#          ('wonderful', 'tasty'): 32,
#          ('tasty', 'taffy'): 3,
#          ('taffy', 'yay'): 1,
#          ('yay', 'barley'): 1,
#          ('barley', 'healthy'): 1,
#          ('healthy', 'dog'): 249,
#          ('food', 'best'): 392,
#          ('best', 'hot'): 392,
#          ('hot', 'sauce'): 599,
#          ('sauce', 'world'): 30,
#          ('world', 'cat'): 3,
#          ('cat', 'love'): 2679,
#          ('love', 'diet'): 16,
#          ('diet', 'food'): 59,
#          ('food', 'better'): 46,
#          ('better', 'regular'): 124,
#          ('regular', 'food'): 2,
#          ('food', 'cat'): 816,
#          ('cat', 'fan'): 4,
#          ('fan', 'new'): 4,
#          ('new', 'food'): 16,
#          ('food', 'fresh'): 10,
#          ('fresh', 'greasy'): 1,
#          ('greasy', 'strawberry'): 1,
#          ('strawberry', 'twizzlers'): 2,
#          ('twizzlers', 'yummy'): 1,
#          ('yummy', 'lot'): 14,
#          ('lot', 'twizzlers'): 1,
#          ('twizzlers', 'expect'): 1,
#          ('expect', 'poor'): 2,
#          ('poor', 'taste'): 53,
#          ('taste', 'love'): 273,
#          ('love', 'great'): 1991,
#          ('great', 'sweet'): 94,
#          ('sweet', 'candy'): 5,
#          ('candy', 'home'): 1,
#          ('home', 'delivered'): 1,
#          ('delivered', 'twizlers'): 1,
#          ('twizlers', 'always'): 1,
#          ('always', 'fresh'): 42,
#          ('fresh', 'twizzlers'): 2,
#          ('twizzlers', 'delicious'): 1,
#          ('delicious', 'product'): 77,
#          ('product', 'twizzlers'): 1,
#          ('twizzlers', 'please'): 1,
#          ('please', 'sell'): 1,
#          ('sell', 'mexico'): 2,
#          ('mexico', 'twizzlers'): 1,
#          ('twizzlers', 'strawberry'): 1,
#          ('strawberry', 'nasty'): 1,
#          ('nasty', 'flavor'): 8,
#          ('flavor', 'great'): 1095,
#          ('great', 'bargain'): 106,
#          ('bargain', 'price'): 37,
#          ('price', 'yummy'): 90,
#          ('yummy', 'best'): 324,
#          ('world', 'great'): 53,
#          ('great', 'machine'): 21,
#          ('machine', 'taste'): 6,
#          ('taste', 'best'): 457,
#          ('best', 'instant'): 271,
#          ('instant', 'oatmeal'): 93,
#          ('oatmeal', 'good'): 45,
#          ('good', 'instant'): 90,
#          ('instant', 'great'): 19,
#          ('great', 'irish'): 13,
#          ('irish', 'oatmeal'): 19,
#          ('oatmeal', 'hurry'): 1,
#          ('hurry', 'satisfying'): 1,
#          ('satisfying', 'love'): 7,
#          ('love', 'gluten'): 30,
#          ('gluten', 'free'): 2663,
#          ('free', 'oatmeal'): 16,
#          ('oatmeal', 'oatmeal'): 13,
#          ('good', 'way'): 171,
#          ('way', 'start'): 113,
#          ('start', 'day'): 185,
#          ('day', 'wife'): 1,
#          ('wife', 'favorite'): 42,
#          ('favorite', 'breakfast'): 53,
#          ('breakfast', 'would'): 1,
#          ('would', 'buy'): 244,
#          ('buy', 'oatmeal'): 2,
#          ('oatmeal', 'mcanns'): 1,
#          ('mcanns', 'taste'): 1,
#          ('taste', 'great'): 3572,
#          ('great', 'oatmeal'): 82,
#          ('oatmeal', 'lover'): 4,
#          ('lover', 'good'): 111,
#          ('good', 'hot'): 201,
#          ('hot', 'breakfast'): 13,
#          ('breakfast', 'great'): 70,
#          ('great', 'taste'): 3692,
#          ('taste', 'convenience'): 24,
#          ('convenience', 'hearty'): 1,
#          ('hearty', 'oatmeal'): 4,
#          ('good', 'mushy'): 3,
#          ('mushy', 'good'): 9,
#          ('good', 'next'): 7,
#          ('next', 'time'): 18,
#          ('time', 'wo'): 1,
#          ('wo', 'order'): 28,
#          ('order', 'variety'): 3,
#          ('variety', 'pack'): 207,
#          ('pack', 'stuff'): 1,
#          ('stuff', 'like'): 50,
#          ('like', 'hot'): 115,
#          ('hot', 'good'): 62,
#          ('good', 'came'): 2,
#          ('came', 'back'): 3,
#          ('back', 'go'): 1,
#          ('go', 'nut'): 90,
#          ('nut', 'peanut'): 6,
#          ('peanut', 'as'): 1,
#          ('as', 'kickin'): 8,
#          ('kickin', 'roast'): 1,
#          ('roast', 'smooth'): 23,
#          ('smooth', 'brew'): 6,
#          ('brew', 'guest'): 1,
#          ('guest', 'love'): 6,
#          ('love', 'awesome'): 171,
#          ('awesome', 'deal'): 49,
#          ('deal', 'go'): 1,
#          ('go', 'wrong'): 160,
#          ('wrong', 'awsome'): 1,
#          ('awsome', 'kid'): 1,
#          ('kid', 'neighborhood'): 1,
#          ('neighborhood', 'loved'): 1,
#          ('loved', 'u'): 2,
#          ('u', 'great'): 37,
#          ('great', 'deal'): 977,
#          ('deal', 'better'): 13,
#          ('better', 'price'): 169,
#          ('price', 'target'): 2,
#          ('target', 'pretty'): 1,
#          ('pretty', 'expensive'): 3,
#          ('expensive', 'stale'): 2,
#          ('stale', 'product'): 31,
#          ('product', 'hammer'): 1,
#          ('hammer', 'nutrition'): 1,
#          ('nutrition', 'fizz'): 1,
#          ('fizz', 'rock'): 1,
#          ('rock', 'great'): 64,
#          ('great', 'source'): 83,
#          ('source', 'electrolyte'): 1,
#          ('electrolyte', 'great'): 2,
#          ('great', 'preventing'): 1,
#          ('preventing', 'cramp'): 1,
#          ('cramp', 'low'): 1,
#          ('low', 'carb'): 489,
#          ('carb', 'alternative'): 5,
#          ('alternative', 'gatorade'): 4,
#          ('gatorade', 'taste'): 4,
#          ('taste', 'good'): 2347,
#          ('good', 'much'): 93,
#          ('much', 'would'): 4,
#          ('would', 'pay'): 10,
#          ('pay', 'bag'): 3,
#          ('bag', 'chocolate'): 3,
#          ('chocolate', 'pretzel'): 8,
#          ('pretzel', 'pretzel'): 16,
#          ('pretzel', 'great'): 66,
#          ('great', 'gummi'): 9,
#          ('gummi', 'bigger'): 1,
#          ('bigger', 'brand'): 1,
#          ('brand', 'best'): 40,
#          ('best', 'ever'): 811,
#          ('ever', 'latice'): 2,
#          ('latice', 'tart'): 1,
#          ('tart', 'warning'): 1,
#          ('warning', 'warning'): 24,
#          ('warning', 'sugar'): 19,
#          ('sugar', 'nothing'): 8,
#          ('nothing', 'special'): 288,
#          ('special', 'tea'): 9,
#          ('tea', 'flavor'): 92,
#          ('flavor', 'good'): 745,
#          ('good', 'taste'): 1365,
#          ('great', 'order'): 19,
#          ('order', 'cold'): 3,
#          ('cold', 'weather'): 15,
#          ('weather', 'best'): 3,
#          ('best', 'delicious'): 158,
#          ('delicious', 'great'): 1086,
#          ('great', 'forget'): 1,
#          ('forget', 'molecular'): 1,
#          ('molecular', 'gastronomy'): 4,
#          ('gastronomy', 'stuff'): 1,
#          ('stuff', 'rockes'): 1,
#          ('rockes', 'coffee'): 1,
#          ('coffee', 'creamer'): 31,
#          ('creamer', 'natural'): 3,
#          ('natural', 'balance'): 77,
#          ('balance', 'lamb'): 3,
#          ('lamb', 'rice'): 21,
#          ('rice', 'increased'): 1,
#          ('increased', 'dog'): 1,
#          ('dog', 'itching'): 1,
#          ('itching', 'great'): 1,
#          ('great', 'food'): 997,
#          ('food', 'great'): 1076,
#          ('great', 'dog'): 1009,
#          ('dog', 'allergy'): 131,
#          ('allergy', 'great'): 74,
#          ('great', 'stomach'): 7,
#          ('stomach', 'problem'): 42,
#          ('problem', 'better'): 9,
#          ('better', 'life'): 5,
#          ('life', 'dog'): 9,
#          ('dog', 'great'): 415,
#          ('food', 'dog'): 703,
#          ('dog', 'sensitive'): 57,
#          ('sensitive', 'stomach'): 115,
#          ('stomach', 'great'): 37,
#          ('food', 'mmmmm'): 2,
#          ('mmmmm', 'mmmmm'): 7,
#          ('mmmmm', 'good'): 45,
#          ('good', 'great'): 1678,
#          ('food', 'convenient'): 13,
#          ('convenient', 'good'): 68,
#          ('good', 'healthy'): 287,
#          ('great', 'allergy'): 27,
#          ('allergy', 'sensitive'): 5,
#          ('sensitive', 'dog'): 30,
#          ('dog', 'love'): 5828,
#          ('love', 'perfect'): 152,
#          ('perfect', 'english'): 6,
#          ('english', 'bulldog'): 22,
#          ('bulldog', 'allergy'): 1,
#          ('allergy', 'bad'): 3,
#          ('bad', 'taste'): 321,
#          ('taste', 'wise'): 16,
#          ('wise', 'star'): 7,
#          ('star', 'item'): 13,
#          ('item', 'great'): 146,
#          ('great', 'support'): 7,
#          ('support', 'tart'): 7,
#          ('tart', 'omaha'): 7,
#          ('omaha', 'apple'): 7,
#          ('apple', 'tartlet'): 7,
#          ('tartlet', 'loved'): 7,
#          ('loved', 'tartlet'): 7,
#          ('tartlet', 'best'): 7,
#          ('best', 'disappointing'): 18,
#          ('disappointing', 'wasting'): 1,
#          ('wasting', 'vinegar'): 1,
#          ('vinegar', 'cucumber'): 1,
#          ('cucumber', 'shame'): 1,
#          ('shame', 'asparagus'): 1,
#          ('asparagus', 'bliss'): 1,
#          ('bliss', 'idea'): 2,
#          ('idea', 'good'): 37,
#          ('good', 'diet'): 26,
#          ('food', 'low'): 9,
#          ('carb', 'angel'): 2,
#          ('angel', 'food'): 9,
#          ('food', 'puff'): 1,
#          ('puff', 'delicious'): 6,
#          ('delicious', 'tea'): 410,
#          ('tea', 'every'): 23,
#          ('every', 'day'): 188,
#          ('day', 'green'): 6,
#          ('green', 'tea'): 1945,
#          ('tea', 'best'): 988,
#          ('best', 'tea'): 875,
#          ('tea', 'ever'): 739,
#          ('ever', 'freah'): 4,
#          ('freah', 'bright'): 4,
#          ('bright', 'clean'): 5,
#          ('clean', 'tea'): 5,
#          ('tea', 'review'): 75,
#          ('review', 'wonderful'): 14,
#          ('wonderful', 'tea'): 289,
#          ('tea', 'great'): 1931,
#          ('great', 'cooky'): 302,
#          ('cooky', 'best'): 149,
#          ('best', 'everyday'): 17,
#          ('everyday', 'cookie'): 1,
#          ('cookie', 'far'): 1,
#          ('far', 'good'): 258,
#          ('good', 'best'): 604,
#          ('best', 'cat'): 252,
#          ('cat', 'food'): 1794,
#          ('food', 'perfect'): 59,
#          ('perfect', 'cat'): 27,
#          ('food', 'older'): 19,
#          ('older', 'cat'): 41,
#          ('cat', 'good'): 75,
#          ('good', 'feline'): 5,
#          ('feline', 'uti'): 4,
#          ('uti', 'palatable'): 4,
#          ('palatable', 'healthy'): 5,
#          ('healthy', 'healthy'): 30,
#          ('healthy', 'love'): 57,
#          ('love', 'wonderful'): 104,
#          ('wonderful', 'food'): 32,
#          ('perfect', 'allergic'): 6,
#          ('allergic', 'kitty'): 6,
#          ('kitty', 'holistic'): 4,
#          ('holistic', 'select'): 47,
#          ('select', 'cat'): 4,
#          ('food', 'taste'): 91,
#          ('great', 'love'): 266,
#          ('love', 'hot'): 87,
#          ('hot', 'spicy'): 79,
#          ('spicy', 'bad'): 4,
#          ('bad', 'price'): 158,
#          ('price', 'favorite'): 71,
#          ('favorite', 'ramen'): 10,
#          ('ramen', 'burn'): 1,
#          ('burn', 'amazing'): 2,
#          ('amazing', 'last'): 1,
#          ('last', 'bite'): 11,
#          ('bite', 'great'): 41,
#          ('great', 'spicy'): 71,
#          ('spicy', 'flavor'): 18,
#          ('great', 'value'): 1359,
#          ('value', 'convenient'): 8,
#          ('convenient', 'ramen'): 1,
#          ('ramen', 'great'): 4,
#          ('great', 'flavor'): 1724,
#          ('flavor', 'taste'): 243,
#          ('great', 'cheaper'): 11,
#          ('cheaper', 'locally'): 8,
#          ('locally', 'taste'): 3,
#          ('taste', 'awesome'): 108,
#          ('awesome', 'look'): 3,
#          ('look', 'beautiful'): 4,
#          ('beautiful', 'happy'): 3,
#          ('happy', 'face'): 1,
#          ('face', 'simply'): 1,
#          ('simply', 'best'): 523,
#          ('best', 'excellent'): 137,
#          ('excellent', 'saver'): 1,
#          ('saver', 'nice'): 2,
#          ('nice', 'snack'): 94,
#          ('snack', 'good'): 372,
#          ('good', 'licorice'): 16,
#          ('licorice', 'love'): 10,
#          ('great', 'kid'): 172,
#          ('kid', 'bite'): 1,
#          ('bite', 'sized'): 32,
#          ('sized', 'sweet'): 1,
#          ('sweet', 'nice'): 27,
#          ('nice', 'kick'): 27,
#          ('kick', 'broken'): 1,
#          ('broken', 'bottle'): 9,
#          ('bottle', 'bottom'): 1,
#          ('bottom', 'love'): 1,
#          ('love', 'salsa'): 10,
#          ('salsa', 'ehhh'): 1,
#          ('ehhh', 'awesome'): 1,
#          ('awesome', 'cornmeal'): 4,
#          ('cornmeal', 'great'): 3,
#          ('great', 'marinade'): 31,
#          ('marinade', 'awesome'): 3,
#          ('awesome', 'stuff'): 87,
#          ('stuff', 'taste'): 159,
#          ('good', 'rip'): 9,
#          ('rip', 'price'): 14,
#          ('price', 'great'): 1203,
#          ('deal', 'great'): 343,
#          ('great', 'tasting'): 2247,
#          ('tasting', 'sea'): 2,
#          ('sea', 'salt'): 347,
#          ('salt', 'iodine'): 1,
#          ('iodine', 'taste'): 1,
#          ('taste', 'fresh'): 59,
#          ('fresh', 'simple'): 1,
#          ('simple', 'good'): 16,
#          ('good', 'tasty'): 313,
#          ('tasty', 'greatest'): 2,
#          ('greatest', 'tasting'): 8,
#          ('tasting', 'bad'): 8,
#          ('bad', 'right'): 2,
#          ('right', 'size'): 80,
#          ('size', 'taste'): 7,
#          ('taste', 'tasteless'): 2,
#          ('tasteless', 'low'): 1,
#          ('low', 'calorie'): 401,
#          ('calorie', 'stuff'): 5,
#          ('stuff', 'sooooo'): 3,
#          ('sooooo', 'good'): 48,
#          ('best', 'stuff'): 133,
#          ('stuff', 'ever'): 52,
#          ('ever', 'low'): 6,
#          ('low', 'quality'): 90,
#          ('quality', 'banana'): 1,
#          ('banana', 'runt'): 6,
#          ('runt', 'banana'): 2,
#          ('banana', 'head'): 3,
#          ('head', 'banana'): 3,
#          ('runt', 'worked'): 3,
#          ('worked', 'great'): 89,
#          ('great', 'ricore'): 1,
#          ('ricore', 'forever'): 1,
#          ('forever', 'delicious'): 1,
#          ('delicious', 'fluffy'): 1,
#          ('fluffy', 'soft'): 2,
#          ('soft', 'delicious'): 25,
#          ('delicious', 'sugary'): 2,
#          ('sugary', 'sweet'): 18,
#          ('sweet', 'great'): 161,
#          ('good', 'back'): 4,
#          ('back', 'day'): 4,
#          ('day', 'teen'): 1,
#          ('teen', 'excellent'): 1,
#          ('excellent', 'lemon'): 5,
#          ('lemon', 'juice'): 38,
#          ('juice', 'great'): 50,
#          ('great', 'product'): 7225,
#          ('product', 'handy'): 7,
#          ('handy', 'realemon'): 1,
#          ('realemon', 'juice'): 2,
#          ('juice', 'amazon'): 2,
#          ('amazon', 'relaxing'): 1,
#          ('relaxing', 'almost'): 1,
#          ('almost', 'like'): 71,
#          ('like', 'something'): 13,
#          ('something', 'smoke'): 1,
#          ('smoke', 'never'): 1,
#          ('never', 'paid'): 1,
#          ('paid', 'much'): 5,
#          ('much', 'marley'): 1,
#          ('marley', 'mellow'): 2,
#          ('mellow', 'mood'): 4,
#          ('mood', 'lite'): 1,
#          ('lite', 'half'): 1,
#          ('half', 'tea'): 3,
#          ('tea', 'half'): 5,
#          ('half', 'lemonade'): 6,
#          ('lemonade', 'great'): 10,
#          ('product', 'help'): 26,
#          ('help', 'sleep'): 23,
#          ('sleep', 'perfect'): 2,
#          ('perfect', 'chocolate'): 33,
#          ('chocolate', 'chip'): 314,
#          ('chip', 'cooky'): 127,
#          ('cooky', 'garbonzo'): 1,
#          ('garbonzo', 'bean'): 2,
#          ('bean', 'flour'): 12,
#          ('flour', 'yum'): 1,
#          ('yum', 'falafel'): 1,
#          ('falafel', 'make'): 1,
#          ('make', 'fresh'): 1,
#          ('fresh', 'fruit'): 27,
#          ('fruit', 'tart'): 2,
#          ('tart', 'light'): 1,
#          ('light', 'beautiful'): 1,
#          ('beautiful', 'miracle'): 1,
#          ('miracle', 'bad'): 1,
#          ('bad', 'instant'): 12,
#          ('instant', 'healthy'): 2,
#          ('healthy', 'coffee'): 5,
#          ('coffee', 'ok'): 93,
#          ('ok', 'love'): 25,
#          ('taste', 'health'): 10,
#          ('health', 'benefit'): 106,
#          ('benefit', 'taste'): 14,
#          ('great', 'arrived'): 4,
#          ('arrived', 'day'): 11,
#          ('day', 'great'): 124,
#          ('great', 'lunch'): 58,
#          ('lunch', 'nice'): 5,
#          ('nice', 'little'): 68,
#          ('little', 'mint'): 12,
#          ('mint', 'pricey'): 2,
#          ('pricey', 'altoids'): 1,
#          ('altoids', 'mini'): 1,
#          ('mini', 'mint'): 3,
#          ('mint', 'tin'): 4,
#          ('tin', 'altoids'): 1,
#          ('altoids', 'sugarfree'): 1,
#          ('sugarfree', 'tasty'): 1,
#          ('tasty', 'mint'): 6,
#          ('mint', 'awesome'): 9,
#          ('awesome', 'altoids'): 2,
#          ('altoids', 'small'): 3,
#          ('small', 'love'): 11,
#          ('love', 'reusable'): 3,
#          ('reusable', 'container'): 1,
#          ('container', 'altoids'): 1,
#          ('altoids', 'huge'): 1,
#          ('huge', 'hit'): 40,
#          ('hit', 'office'): 12,
#          ('office', 'love'): 11,
#          ('love', 'fresh'): 29,
#          ('fresh', 'wintergreen'): 1,
#          ('wintergreen', 'breath'): 1,
#          ('breath', 'mint'): 11,
#          ('mint', 'better'): 7,
#          ('better', 'average'): 39,
#          ('average', 'expensive'): 1,
#          ('expensive', 'average'): 2,
#          ('average', 'cat'): 1,
#          ('great', 'fat'): 17,
#          ('fat', 'cat'): 17,
#          ('cat', 'senior'): 8,
#          ('senior', 'citizen'): 8,
#          ('citizen', 'nearly'): 1,
#          ('nearly', 'killed'): 1,
#          ('killed', 'cat'): 1,
#          ('cat', 'changed'): 1,
#          ('changed', 'formula'): 108,
#          ('formula', 'make'): 11,
#          ('make', 'cat'): 29,
#          ('cat', 'sick'): 33,
#          ('sick', 'best'): 4,
#          ('best', 'case'): 2,
#          ('case', 'looking'): 1,
#          ('looking', 'different'): 1,
#          ('different', 'flavor'): 52,
#          ('flavor', 'price'): 31,
#          ('price', 'correct'): 4,
#          ('correct', 'mccormick'): 1,
#          ('mccormick', 'brand'): 1,
#          ('brand', 'ahmad'): 1,
#          ('ahmad', 'loose'): 1,
#          ('loose', 'imperial'): 1,
#          ('imperial', 'blend'): 1,
#          ('blend', 'tea'): 13,
#          ('great', 'price'): 3237,
#          ('price', 'nice'): 101,
#          ('nice', 'tea'): 152,
#          ('tea', 'fragrant'): 41,
#          ('fragrant', 'tea'): 19,
#          ('best', 'ahmad'): 2,
#          ('ahmad', 'tea'): 19,
#          ('tea', 'favorite'): 298,
#          ('favorite', 'tea'): 596,
#          ('ever', 'real'): 32,
#          ('real', 'tea'): 43,
#          ('tea', 'delicious'): 556,
#          ('delicious', 'best'): 621,
#          ('best', 'bloody'): 16,
#          ('bloody', 'mary'): 47,
#          ('mary', 'mixer'): 1,
#          ('mixer', 'best'): 3,
#          ('best', 'mcclures'): 1,
#          ('mcclures', 'bloody'): 1,
#          ('mary', 'mix'): 26,
#          ('mix', 'good'): 164,
#          ('good', 'love'): 410,
#          ('love', 'tea'): 868,
#          ('tea', 'really'): 157,
#          ('really', 'nice'): 116,
#          ('nice', 'taste'): 164,
#          ('taste', 'give'): 6,
#          ('give', 'watermelon'): 1,
#          ('watermelon', 'citron'): 1,
#          ('citron', 'sea'): 1,
#          ('salt', 'furniture'): 1,
#          ('furniture', 'polish'): 6,
#          ('polish', 'taste'): 1,
#          ('taste', 'big'): 17,
#          ('big', 'tub'): 4,
#          ('tub', 'salt'): 2,
#          ('salt', 'taste'): 35,
#          ('taste', 'neutral'): 4,
#          ('neutral', 'quantity'): 1,
#          ('quantity', 'deceitful'): 1,
#          ('deceitful', 'eukanuba'): 1,
#          ('eukanuba', 'puppy'): 2,
#          ('puppy', 'small'): 3,
#          ('small', 'breed'): 44,
#          ('breed', 'dog'): 24,
#          ('food', 'high'): 45,
#          ('high', 'quality'): 771,
#          ('quality', 'gave'): 3,
#          ('gave', 'dog'): 34,
#          ('dog', 'wicked'): 1,
#          ('wicked', 'gas'): 1,
#          ('gas', 'great'): 8,
#          ('tasting', 'green'): 68,
#          ('deal', 'omg'): 2,
#          ('omg', 'best'): 52,
#          ('best', 'chocolate'): 427,
#          ('chocolate', 'jelly'): 6,
#          ('jelly', 'belly'): 178,
#          ('belly', 'excellent'): 3,
#          ('excellent', 'loose'): 5,
#          ('loose', 'tea'): 107,
#          ('tea', 'good'): 1056,
#          ('good', 'anytime'): 19,
#          ('anytime', 'hot'): 2,
#          ('hot', 'tea'): 27,
#          ('tea', 'everyday'): 16,
#          ('everyday', 'cup'): 6,
#          ('cup', 'tea'): 348,
#          ('tea', 'get'): 47,
#          ('get', 'store'): 19,
#          ('store', 'ahmad'): 1,
#          ('tea', 'disappointed'): 50,
#          ('disappointed', 'wonderful'): 6,
#          ('wonderful', 'best'): 82,
#          ('best', 'way'): 129,
#          ('way', 'buy'): 87,
#          ('buy', 'kcups'): 2,
#          ('kcups', 'delicious'): 4,
#          ('delicious', 'keep'): 7,
#          ('keep', 'dentest'): 1,
#          ('dentest', 'chair'): 1,
#          ('chair', 'super'): 1,
#          ('super', 'superfoods'): 1,
#          ('superfoods', 'super'): 1,
#          ('super', 'easy'): 64,
#          ('easy', 'pok'): 1,
#          ('pok', 'chop'): 5,
#          ('chop', 'sad'): 1,
#          ('sad', 'outcome'): 1,
#          ('outcome', 'best'): 1,
#          ('best', 'energy'): 97,
#          ('energy', 'shot'): 45,
#          ('shot', 'waste'): 1,
#          ('waste', 'money'): 539,
#          ('money', 'ca'): 2,
#          ('ca', 'handle'): 6,
#          ('handle', 'caffeine'): 2,
#          ('caffeine', 'yum'): 6,
#          ('yum', 'yummy'): 136,
#          ('yummy', 'yummier'): 1,
#          ('yummier', 'reek'): 1,
#          ('reek', 'like'): 1,
#          ('like', 'chemical'): 32,
#          ('chemical', 'disappointed'): 1,
#          ('disappointed', 'great'): 134,
#          ('great', 'lifestyle'): 1,
#          ('lifestyle', 'dog'): 1,
#          ('love', 'yummy'): 267,
#          ('yummy', 'sugar'): 23,
#          ('sugar', 'raw'): 17,
#          ('raw', 'manufacturing'): 1,
#          ('manufacturing', 'problem'): 3,
#          ('problem', 'diminish'): 1,
#          ('diminish', 'product'): 1,
#          ('product', 'good'): 1112,
#          ('good', 'product'): 2340,
#          ('product', 'terrible'): 77,
#          ('terrible', 'agricultural'): 1,
#          ('agricultural', 'practice'): 1,
#          ('practice', 'sugar'): 1,
#          ('raw', 'sugar'): 14,
#          ('raw', 'lie'): 1,
#          ('lie', 'sugar'): 1,
#          ('sugar', 'excellent'): 39,
#          ('excellent', 'perfect'): 18,
#          ('perfect', 'good'): 60,
#          ('product', 'never'): 24,
#          ('never', 'use'): 26,
#          ('use', 'white'): 3,
#          ('white', 'sugar'): 18,
#          ('sugar', 'thanks'): 1,
#          ('thanks', 'review'): 2,
#          ('review', 'scott'): 1,
#          ('scott', 'great'): 2,
#          ('great', 'awesome'): 101,
#          ('awesome', 'sugar'): 9,
#          ('sugar', 'great'): 175,
#          ('product', 'weak'): 10,
#          ('weak', 'packaging'): 2,
#          ('packaging', 'excellent'): 20,
#          ('excellent', 'excellent'): 85,
#          ('excellent', 'amazing'): 19,
#          ('amazing', 'tasty'): 42,
#          ('tasty', 'chip'): 76,
#          ('chip', 'yummy'): 144,
#          ('yummy', 'excellent'): 147,
#          ('excellent', 'taste'): 410,
#          ('taste', 'priced'): 9,
#          ('priced', 'chip'): 1,
#          ('chip', 'lack'): 1,
#          ('lack', 'rice'): 1,
#          ('rice', 'taste'): 10,
#          ('taste', 'rotel'): 1,
#          ('rotel', 'save'): 1,
#          ('save', 'daily'): 1,
#          ('daily', 'basis'): 2,
#          ('basis', 'fabulous'): 1,
#          ('fabulous', 'amazon'): 2,
#          ('amazon', 'expensive'): 11,
#          ('expensive', 'mild'): 2,
#          ('mild', 'enough'): 1,
#          ('enough', 'lol'): 1,
#          ('lol', 'great'): 9,
#          ('great', 'natural'): 177,
#          ('natural', 'energy'): 27,
#          ('energy', 'like'): 10,
#          ('like', 'stuff'): 33,
#          ('stuff', 'great'): 852,
#          ('great', 'energy'): 119,
#          ('energy', 'sure'): 3,
#          ('sure', 'best'): 8,
#          ('shot', 'smooth'): 2,
#          ('smooth', 'organic'): 3,
#          ('organic', 'fantastic'): 2,
#          ('fantastic', 'natural'): 7,
#          ('energy', 'way'): 1,
#          ('way', 'better'): 168,
#          ('better', 'guayaki'): 1,
#          ('guayaki', 'taste'): 1,
#          ('good', 'provides'): 2,
#          ('provides', 'energy'): 2,
#          ('energy', 'rocket'): 1,
#          ('rocket', 'bottle'): 1,
#          ('bottle', 'stuff'): 3,
#          ('stuff', 'work'): 71,
#          ('work', 'favorite'): 9,
#          ('favorite', 'energy'): 31,
#          ('shot', 'natural'): 1,
#          ('natural', 'natural'): 13,
#          ('energy', 'boost'): 98,
#          ('boost', 'best'): 9,
#          ('shot', 'ever'): 7,
#          ('ever', 'tasted'): 447,
#          ('tasted', 'best'): 38,
#          ('best', 'tested'): 2,
#          ('tested', 'trucker'): 2,
#          ('trucker', 'good'): 1,
#          ('good', 'stuff'): 2835,
#          ('energy', 'drink'): 438,
#          ('drink', 'without'): 27,
#          ('without', 'artificial'): 7,
#          ('artificial', 'ingredient'): 16,
#          ('ingredient', 'flavor'): 4,
#          ('flavor', 'getting'): 1,
#          ('getting', 'better'): 8,
#          ('better', 'energy'): 16,
#          ('energy', 'great'): 61,
#          ('great', 'awful'): 16,
#          ('awful', 'barely'): 1,
#          ('barely', 'describe'): 1,
#          ('describe', 'could'): 1,
#          ('could', 'use'): 61,
#          ('use', 'vanilla'): 1,
#          ('vanilla', 'tootsie'): 6,
#          ('tootsie', 'roll'): 28,
#          ('roll', 'one'): 3,
#          ('one', 'favoritte'): 1,
#          ('favoritte', 'food'): 1,
#          ('food', 'fantastic'): 60,
#          ('fantastic', 'wow'): 6,
#          ('wow', 'dissapointed'): 1,
#          ('dissapointed', 'quantity'): 1,
#          ('quantity', 'good'): 12,
#          ('good', 'coffee'): 2210,
#          ('coffee', 'tasty'): 121,
#          ('tasty', 'excellent'): 60,
#          ('excellent', 'coffee'): 614,
#          ('coffee', 'hot'): 29,
#          ('hot', 'hot'): 210,
#          ('hot', 'delicious'): 28,
#          ('delicious', 'swiss'): 3,
#          ('swiss', 'chalet'): 1,
#          ('chalet', 'oyster'): 1,
#          ('oyster', 'sauce'): 10,
#          ('sauce', 'absolutely'): 4,
#          ('absolutely', 'delicious'): 481,
#          ('great', 'gag'): 11,
#          ('gag', 'gift'): 17,
#          ('gift', 'arrived'): 2,
#          ('arrived', 'fast'): 7,
#          ('fast', 'penguin'): 1,
#          ('penguin', 'pooper'): 1,
#          ('pooper', 'never'): 1,
#          ('never', 'arrived'): 23,
#          ('arrived', 'coffee'): 1,
#          ('creamer', 'hazelnut'): 2,
#          ('hazelnut', 'broken'): 1,
#          ('broken', 'creamer'): 1,
#          ('creamer', 'shipped'): 1,
#          ('shipped', 'great'): 5,
#          ('great', 'better'): 62,
#          ('better', 'packaging'): 24,
#          ('packaging', 'creamer'): 1,
#          ('creamer', 'perfect'): 1,
#          ('perfect', 'work'): 13,
#          ('work', 'awful'): 4,
#          ('awful', 'work'): 5,
#          ('work', 'art'): 14,
#          ('art', 'yes'): 1,
#          ('yes', 'real'): 8,
#          ('real', 'excellent'): 2,
#          ('coffee', 'taste'): 326,
#          ('good', 'king'): 5,
#          ('king', 'seasoning'): 1,
#          ('seasoning', 'salt'): 26,
#          ('salt', 'toasted'): 1,
#          ('toasted', 'sesame'): 6,
#          ('sesame', 'oil'): 23,
#          ('oil', 'tasty'): 15,
#          ('tasty', 'tasty'): 121,
#          ('tasty', 'love'): 131,
#          ('love', 'love'): 1793,
#          ('great', 'eating'): 15,
#          ('eating', 'whole'): 3,
#          ('whole', 'food'): 60,
#          ('food', 'clean'): 3,
#          ('clean', 'veggie'): 1,
#          ('veggie', 'brush'): 1,
#          ('brush', 'absolutely'): 1,
#          ('absolutely', 'love'): 134,
#          ('love', 'good'): 929,
#          ('good', 'ice'): 10,
#          ('ice', 'great'): 7,
#          ('great', 'teething'): 9,
#          ('teething', 'wonderful'): 1,
#          ('wonderful', 'clean'): 2,
#          ('clean', 'impressed'): 1,
#          ('impressed', 'love'): 5,
#          ('fresh', 'food'): 5,
#          ('food', 'feeder'): 1,
#          ('feeder', 'great'): 1,
#          ('great', 'bean'): 102,
#          ('bean', 'good'): 94,
#          ('stuff', 'excellent'): 188,
#          ('excellent', 'exactly'): 9,
#          ('exactly', 'expected'): 77,
#          ('expected', 'best'): 39,
#          ('best', 'love'): 171,
#          ('love', 'product'): 762,
#          ('product', 'great'): 2333,
#          ('price', 'line'): 11,
#          ('line', 'swedish'): 1,
#          ('swedish', 'pearl'): 1,
#          ('pearl', 'belgian'): 1,
#          ('belgian', 'pearl'): 2,
#          ('pearl', 'perfect'): 1,
#          ('perfect', 'great'): 131,
#          ('taste', 'wine'): 5,
#          ('wine', 'maker'): 3,
#          ('maker', 'excellent'): 4,
#          ('excellent', 'everyday'): 3,
#          ('everyday', 'olive'): 2,
#          ('olive', 'oil'): 541,
#          ('oil', 'love'): 80,
#          ('love', 'weaver'): 2,
#          ('weaver', 'fan'): 1,
#          ('fan', 'make'): 2,
#          ('make', 'day'): 5,
#          ('day', 'treat'): 5,
#          ('treat', 'best'): 291,
#          ('best', 'coffee'): 1283,
#          ('coffee', 'bitter'): 53,
#          ('bitter', 'drinking'): 1,
#          ('drinking', 'love'): 2,
#          ('love', 'latin'): 1,
#          ('latin', 'america'): 1,
#          ('america', 'aroma'): 1,
#          ('aroma', 'great'): 49,
#          ('great', 'snack'): 1572,
#          ('snack', 'best'): 209,
#          ('best', 'bar'): 131,
#          ('bar', 'ca'): 14,
#          ('ca', 'find'): 173,
#          ('find', 'anywhere'): 38,
#          ('anywhere', 'else'): 34,
#          ('else', 'new'): 3,
#          ('new', 'granola'): 1,
#          ('granola', 'bar'): 323,
#          ('bar', 'another'): 19,
#          ('another', 'husband'): 1,
#          ('husband', 'favorite'): 62,
#          ('favorite', 'price'): 6,
#          ('price', 'surprise'): 2,
#          ('surprise', 'smooth'): 1,
#          ('smooth', 'coffee'): 166,
#          ('coffee', 'highly'): 33,
#          ('highly', 'recommended'): 460,
#          ('recommended', 'saving'): 1,
#          ('saving', 'grace'): 10,
#          ('grace', 'green'): 9,
#          ('green', 'mountain'): 639,
#          ('mountain', 'coffee'): 221,
#          ('coffee', 'favorite'): 382,
#          ('favorite', 'good'): 241,
#          ('coffee', 'nantucket'): 42,
#          ('nantucket', 'blend'): 48,
#          ('blend', 'fantastic'): 5,
#          ('fantastic', 'chicken'): 4,
#          ('chicken', 'noodle'): 43,
#          ('noodle', 'soup'): 62,
#          ('soup', 'greatest'): 1,
#          ('greatest', 'oil'): 1,
#          ('oil', 'since'): 1,
#          ('since', 'slice'): 1,
#          ('slice', 'bread'): 2,
#          ('bread', 'best'): 72,
#          ('ever', 'deliciously'): 3,
#          ('deliciously', 'scrumptious'): 1,
#          ('scrumptious', 'heinz'): 1,
#          ('heinz', 'really'): 1,
#          ('really', 'good'): 1469,
#          ('stuff', 'disappointing'): 9,
#          ('disappointing', 'waste'): 1,
#          ('money', 'porcini'): 1,
#          ('porcini', 'mushroom'): 14,
#          ('mushroom', 'excellent'): 3,
#          ('excellent', 'product'): 1667,
#          ('product', 'excellent'): 446,
#          ('excellent', 'flavor'): 309,
#          ('flavor', 'mostly'): 22,
#          ('mostly', 'large'): 1,
#          ('large', 'piece'): 1,
#          ('piece', 'best'): 3,
#          ('best', 'good'): 325,
#          ('good', 'money'): 25,
#          ('money', 'highest'): 1,
#          ('highest', 'quality'): 48,
#          ('quality', 'good'): 207,
#          ('good', 'price'): 1604,
#          ('price', 'fresh'): 40,
#          ('fresh', 'whole'): 9,
#          ('whole', 'perfect'): 1,
#          ('perfect', 'fresh'): 2,
#          ('fresh', 'tasty'): 108,
#          ('tasty', 'valentine'): 5,
#          ('valentine', 'gift'): 7,
#          ('gift', 'winner'): 3,
#          ('winner', 'cat'): 13,
#          ('cat', 'wo'): 162,
#          ('wo', 'go'): 18,
#          ('go', 'near'): 11,
#          ('near', 'simply'): 1,
#          ('simply', 'wild'): 3,
#          ('wild', 'chick'): 1,
#          ('chick', 'brown'): 1,
#          ('brown', 'rice'): 278,
#          ('rice', 'cat'): 18,
#          ('cat', 'ham'): 1,
#          ('ham', 'base'): 11,
#          ('base', 'msg'): 2,
#          ('msg', 'ham'): 1,
#          ('base', 'delisious'): 1,
#          ('delisious', 'pancake'): 1,
#          ('pancake', 'great'): 23,
#          ('great', 'around'): 33,
#          ('around', 'mix'): 1,
#          ('mix', 'great'): 277,
#          ('great', 'mix'): 109,
#          ('mix', 'perfect'): 14,
#          ('perfect', 'mix'): 12,
#          ('mix', 'arrowhead'): 2,
#          ('arrowhead', 'mill'): 27,
#          ('mill', 'whole'): 5,
#          ('whole', 'grain'): 193,
#          ('grain', 'buttermilk'): 1,
#          ('buttermilk', 'pancake'): 9,
#          ('pancake', 'easy'): 4,
#          ('easy', 'good'): 98,
#          ('good', 'egg'): 10,
#          ('egg', 'allergy'): 8,
#          ('allergy', 'love'): 20,
#          ('product', 'disappointed'): 52,
#          ('disappointed', 'shipping'): 2,
#          ('shipping', 'poor'): 4,
#          ('poor', 'item'): 1,
#          ('item', 'packaging'): 3,
#          ('packaging', 'awful'): 2,
#          ('awful', 'disappointing'): 2,
#          ('disappointing', 'great'): 57,
#          ('great', 'healthy'): 500,
#          ('healthy', 'snack'): 860,
#          ('snack', 'sweet'): 53,
#          ('sweet', 'soothing'): 5,
#          ('soothing', 'minty'): 1,
#          ('minty', 'flavor'): 8,
#          ('flavor', 'ingredient'): 8,
#          ('ingredient', 'take'): 1,
#          ('take', 'second'): 2,
#          ('second', 'read'): 1,
#          ('read', 'fantastic'): 2,
#          ('fantastic', 'healthy'): 28,
#          ('healthy', 'product'): 73,
#          ('excellent', 'tea'): 423,
#          ('tea', 'french'): 4,
#          ('french', 'bag'): 1,
#          ('bag', 'best'): 79,
#          ('best', 'roast'): 6,
#          ('roast', 'ever'): 7,
#          ('ever', 'franch'): 1,
#          ('franch', 'best'): 1,
#          ('best', 'double'): 2,
#          ('double', 'pleasure'): 3,
#          ...})

# %%
def word_frequency(sentence):
    sentence = " ".join(map(str, sentence))
    new_tokens = word_tokenize(sentence)
    new_tokens = [t.lower() for t in new_tokens]
    new_tokens =[t for t in new_tokens if t not in stopwords.words('english')]
    new_tokens = [t for t in new_tokens if t.isalpha()]
    lemmatizer = WordNetLemmatizer()
    new_tokens =[lemmatizer.lemmatize(t) for t in new_tokens]
    counted = Counter(new_tokens)
    counted_2= Counter(ngrams(new_tokens,2))
    counted_3= Counter(ngrams(new_tokens,3))
    word_freq = pd.DataFrame(counted.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)
    word_pairs =pd.DataFrame(counted_2.items(),columns=['pairs','frequency']).sort_values(by='frequency',ascending=False)
    trigrams =pd.DataFrame(counted_3.items(),columns=['trigrams','frequency']).sort_values(by='frequency',ascending=False)
    return word_freq,word_pairs,trigrams

# %%
data2,data3,data4 = word_frequency(df['Summary'])

# %%
data4
# Out:
#                        trigrams  frequency
# 2625    (great, product, great)       1104
# 3498           (dog, love, dog)        651
# 6494    (coffee, great, coffee)        646
# 877          (love, love, love)        605
# 3499          (love, dog, love)        562
# ...                         ...        ...
# 380702  (much, flavor, exactly)          1
# 380704  (exactly, looking, one)          1
# 380705     (looking, one, best)          1
# 380706     (made, great, sweet)          1
# 908121    (treat, great, honey)          1
#
# [908122 rows x 2 columns]

# %%
fig, axes = plt.subplots(3,1,figsize=(8,20))
sns.barplot(ax=axes[0],x='frequency',y='word',data=data2.head(30))
sns.barplot(ax=axes[1],x='frequency',y='pairs',data=data3.head(30))
sns.barplot(ax=axes[2],x='frequency',y='trigrams',data=data4.head(30))
# Out:
# <Axes: xlabel='frequency', ylabel='trigrams'>
